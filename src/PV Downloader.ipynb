# %% [markdown]
# ## Script to download all the monthly PV production data and then unzip and merge the DFs.

# %%
import requests
from pathlib import Path

base_url = "https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/"

years = range(2017, 2023)  
months = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]

file_prefix = "PUBLIC_DVD_ROOFTOP_PV_ACTUAL_"
file_suffix = ".zip"

download_dir = Path("../data/PV_Data/raw_data")  # The specified path
download_dir.mkdir(parents=True, exist_ok=True)

def download_file(url, path):
    response = requests.get(url)
    if response.status_code == 200:
        with open(path, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded {file_name} to {path}")
    else:
        print(f"Failed to download {file_name}: HTTP Status Code {response.status_code}")

for year in years:
    for month in months:
        file_name = f"{file_prefix}{year}{month}010000{file_suffix}"
        full_url = f"{base_url}{year}/MMSDM_{year}_{month}/MMSDM_Historical_Data_SQLLoader/DATA/{file_name}"
        file_path = download_dir / file_name
        
        print(f"Downloading {file_name}...")
        download_file(full_url, file_path)

print("Downloads complete.")
# Out:
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201701010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201701010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201701010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201702010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201702010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201702010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201703010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201703010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201703010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201704010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201704010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201704010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201705010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201705010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201705010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201706010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201706010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201706010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201707010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201707010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201707010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201708010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201708010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201708010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201709010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201709010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201709010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201710010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201710010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201710010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201711010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201711010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201711010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201712010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201712010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201712010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201801010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201801010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201801010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201802010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201802010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201802010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201803010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201803010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201803010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201804010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201804010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201804010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201805010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201805010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201805010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201806010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201806010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201806010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201807010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201807010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201807010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201808010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201808010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201808010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201809010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201809010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201809010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201810010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201810010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201810010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201811010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201811010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201811010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201812010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201812010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201812010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201901010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201901010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201901010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201902010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201902010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201902010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201903010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201903010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201903010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201904010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201904010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201904010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201905010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201905010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201905010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201906010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201906010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201906010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201907010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201907010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201907010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201908010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201908010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201908010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201909010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201909010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201909010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201910010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201910010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201910010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201911010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201911010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201911010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201912010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201912010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201912010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202001010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202001010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202001010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202002010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202002010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202002010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202003010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202003010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202003010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202004010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202004010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202004010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202005010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202005010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202005010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202006010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202006010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202006010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202007010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202007010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202007010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202008010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202008010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202008010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202009010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202009010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202009010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202010010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202010010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202010010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202011010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202011010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202011010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202012010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202012010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202012010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202101010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202101010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202101010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202102010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202102010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202102010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202103010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202103010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202103010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202104010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202104010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202104010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202105010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202105010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202105010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202106010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202106010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202106010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202107010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202107010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202107010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202108010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202108010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202108010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202109010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202109010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202109010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202110010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202110010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202110010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202111010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202111010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202111010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202112010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202112010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202112010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202201010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202201010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202201010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202202010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202202010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202202010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202203010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202203010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202203010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202204010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202204010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202204010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202205010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202205010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202205010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202206010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202206010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202206010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202207010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202207010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202207010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202208010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202208010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202208010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202209010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202209010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202209010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202210010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202210010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202210010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202211010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202211010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202211010000.zip
# Downloading PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202212010000.zip...
# Downloaded PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202212010000.zip to ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202212010000.zip
# Downloads complete.

# %% [markdown]
# ## Script for Unzip

# %%
import zipfile
from pathlib import Path

# Specify the directory with the zip files
zip_files_dir = Path("../data/PV_Data/raw_data")
unzip_dir = zip_files_dir / "unzipped_data"

# Create a directory for the unzipped files if it doesn't exist
unzip_dir.mkdir(parents=True, exist_ok=True)

# Loop through each zip file in the directory and unzip it
for zip_file in zip_files_dir.glob("*.zip"):
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        # Extract all the contents of zip file into the unzipped directory
        zip_ref.extractall(unzip_dir)
        print(f"Unzipped {zip_file} into {unzip_dir}")

print("Unzipping complete.")
# Out:
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202003010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201708010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201804010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201810010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201711010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201705010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202107010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201809010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202206010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201802010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202212010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202005010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202011010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202101010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201906010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202008010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201703010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201912010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201709010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202002010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201811010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202201010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201805010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201704010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201710010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201901010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202112010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202106010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201808010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202207010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201803010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202010010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202004010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201702010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201907010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202009010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202108010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201806010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202202010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201812010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202001010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202105010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202111010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201902010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201707010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201909010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202007010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202204010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202210010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201904010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201701010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201910010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202209010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202103010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202109010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201807010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202203010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202110010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202104010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201706010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201712010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201903010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202012010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201908010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202006010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202211010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201801010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202205010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201911010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201905010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202208010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipped ../data/PV_Data/raw_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202102010000.zip into ../data/PV_Data/raw_data/unzipped_data
# Unzipping complete.

# %% [markdown]
# ## Lets load all the names of the unzipped files so we can compare their structure to make sure they have the same columns

# %%
from pathlib import Path

unzipped_files_dir = Path("../data/PV_Data/raw_data/unzipped_data")

file_paths = []

for file_path in unzipped_files_dir.rglob('*'):
    if file_path.is_file():
        file_paths.append(file_path)
        print(file_path)

print(f"Total files found: {len(file_paths)}")
# Out:
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202005010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202011010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202206010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201802010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202212010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201906010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202008010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201703010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201912010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202101010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201804010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201810010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202003010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201708010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202107010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201809010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201711010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201705010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202010010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202004010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202207010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201803010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201702010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201907010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202009010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201811010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202201010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201805010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201709010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202002010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202112010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202106010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201808010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201704010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201710010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201901010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202204010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202210010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201909010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202007010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202209010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202103010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201904010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201701010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201910010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202001010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202108010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201806010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202202010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201812010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201902010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201707010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202105010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202111010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202211010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201801010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202205010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202012010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201908010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202006010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202208010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202102010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201911010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201905010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202109010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201807010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202203010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201706010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201712010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201903010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202110010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202104010000.CSV
# Total files found: 72

# %%
from pathlib import Path

unzipped_files_dir = Path("../data/PV_Data/raw_data/unzipped_data")

all_files = list(unzipped_files_dir.glob('*'))

for file in all_files:
    print(file)

csv_files = list(unzipped_files_dir.glob('*.csv'))
if csv_files:
    print("CSV files found:")
    for file in csv_files:
        print(file)
else:
    print("No CSV files found in the directory.")
# Out:
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202005010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202011010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202206010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201802010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202212010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201906010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202008010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201703010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201912010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202101010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201804010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201810010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202003010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201708010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202107010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201809010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201711010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201705010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202010010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202004010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202207010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201803010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201702010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201907010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202009010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201811010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202201010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201805010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201709010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202002010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202112010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202106010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201808010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201704010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201710010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201901010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202204010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202210010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201909010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202007010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202209010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202103010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201904010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201701010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201910010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202001010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202108010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201806010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202202010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201812010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201902010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201707010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202105010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202111010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202211010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201801010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202205010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202012010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201908010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202006010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202208010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202102010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201911010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201905010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202109010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201807010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202203010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201706010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201712010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_201903010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202110010000.CSV
# ../data/PV_Data/raw_data/unzipped_data/PUBLIC_DVD_ROOFTOP_PV_ACTUAL_202104010000.CSV
# No CSV files found in the directory.

# %%
from pathlib import Path
import pandas as pd

unzipped_files_dir = Path("../data/PV_Data/raw_data/unzipped_data")

file_paths = []

for file_ext in ['*.CSV', '*.csv']:
    for file_path in unzipped_files_dir.glob(file_ext):
        if file_path.is_file():
            file_paths.append(file_path)

if not file_paths:
    print("No CSV files found in the directory.")
else:
    base_df = pd.read_csv(file_paths[0], header=1)  # Using header=1 to specify second row as header
    base_columns = base_df.columns.tolist()
    print(f"Base columns: {base_columns}")

    all_match = True

    
    for file_path in file_paths[1:]:  
        df = pd.read_csv(file_path, header=1)  # Using header=1 here as well
        if list(df.columns) != base_columns:
            all_match = False
            print(f"Columns in {file_path.name} do not match the base file structure.")

    if all_match:
        print("All files have the same column structure.")
    else:
        print("Some files have a different column structure.")
# Out:
# Base columns: ['I', 'ROOFTOP', 'ACTUAL', '2', 'INTERVAL_DATETIME', 'REGIONID', 'POWER', 'QI', 'TYPE', 'LASTCHANGED']
# All files have the same column structure.

# %% [markdown]
# ## All files have the same structure - Lets go ahead and merge

# %%
import pandas as pd
from pathlib import Path

unzipped_files_dir = Path("../data/PV_Data/raw_data/unzipped_data")

dataframes = []

for file_path in unzipped_files_dir.glob('*.CSV'):
    df = pd.read_csv(file_path, header=1)
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)

combined_csv_path = unzipped_files_dir / "combined_data.csv"
combined_df.to_csv(combined_csv_path, index=False)

print(f"Combined CSV saved to {combined_csv_path}")
# Out:
# Combined CSV saved to ../data/PV_Data/raw_data/unzipped_data/combined_data.csv

# %%
import pandas as pd
from pathlib import Path

combined_csv_path = "../data/PV_Data/raw_data/unzipped_data/combined_data.csv"

combined_df = pd.read_csv(combined_csv_path)

df_info = combined_df.info()

df_description = combined_df.describe()

# Check for missing values
missing_values = combined_df.isnull().sum()

df_info, df_description, missing_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1973762 entries, 0 to 1973761
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   I                  object
#  1   ROOFTOP            object
#  2   ACTUAL             object
#  3   2                  float64
#  4   INTERVAL_DATETIME  object
#  5   REGIONID           object
#  6   POWER              float64
#  7   QI                 float64
#  8   TYPE               object
#  9   LASTCHANGED        object
# dtypes: float64(3), object(7)
# memory usage: 150.6+ MB
# (None,
#                 2         POWER            QI
#  count  1973690.0  1.973020e+06  1.973690e+06
#  mean         2.0  2.014056e+02  8.218299e-01
#  std          0.0  4.315817e+02  1.986320e-01
#  min          2.0  0.000000e+00  0.000000e+00
#  25%          2.0  0.000000e+00  6.000000e-01
#  50%          2.0  1.070000e+00  1.000000e+00
#  75%          2.0  1.533310e+02  1.000000e+00
#  max          2.0  4.104816e+03  1.000000e+00,
#  I                      0
#  ROOFTOP                0
#  ACTUAL                 0
#  2                     72
#  INTERVAL_DATETIME     72
#  REGIONID              72
#  POWER                742
#  QI                    72
#  TYPE                  72
#  LASTCHANGED           72
#  dtype: int64)

# %%
combined_df.head(100)
# Out:
#     I  ROOFTOP  ACTUAL    2    INTERVAL_DATETIME REGIONID  POWER   QI  \
# 0   D  ROOFTOP  ACTUAL  2.0  2020/05/01 00:30:00     NSW1    0.0  1.0
# 1   D  ROOFTOP  ACTUAL  2.0  2020/05/01 00:30:00     NSW1    0.0  0.6
# 2   D  ROOFTOP  ACTUAL  2.0  2020/05/01 00:30:00     QLD1    0.0  1.0
# 3   D  ROOFTOP  ACTUAL  2.0  2020/05/01 00:30:00     QLD1    0.0  0.6
# 4   D  ROOFTOP  ACTUAL  2.0  2020/05/01 00:30:00     QLDC    0.0  1.0
# .. ..      ...     ...  ...                  ...      ...    ...  ...
# 95  D  ROOFTOP  ACTUAL  2.0  2020/05/01 02:30:00     TASN    0.0  0.6
# 96  D  ROOFTOP  ACTUAL  2.0  2020/05/01 02:30:00     TASS    0.0  1.0
# 97  D  ROOFTOP  ACTUAL  2.0  2020/05/01 02:30:00     TASS    0.0  0.6
# 98  D  ROOFTOP  ACTUAL  2.0  2020/05/01 02:30:00     VIC1    0.0  0.6
# 99  D  ROOFTOP  ACTUAL  2.0  2020/05/01 02:30:00     VIC1    0.0  1.0
#
#            TYPE          LASTCHANGED
# 0   MEASUREMENT  2020/05/01 00:50:42
# 1     SATELLITE  2020/05/01 00:50:26
# 2   MEASUREMENT  2020/05/01 00:50:42
# 3     SATELLITE  2020/05/01 00:50:26
# 4   MEASUREMENT  2020/05/01 00:50:42
# ..          ...                  ...
# 95    SATELLITE  2020/05/01 02:50:27
# 96  MEASUREMENT  2020/05/01 02:50:42
# 97    SATELLITE  2020/05/01 02:50:27
# 98    SATELLITE  2020/05/01 02:50:27
# 99  MEASUREMENT  2020/05/01 02:50:42
#
# [100 rows x 10 columns]

# %% [markdown]
# ## Looks like theres a couple "Regions" for QLD etc - merge all the duplicates into one....

# %%
unique_regionids = combined_df['REGIONID'].unique()

print("Unique REGIONID values:")
print(unique_regionids)
# Out:
# Unique REGIONID values:
# ['NSW1' 'QLD1' 'QLDC' 'QLDN' 'QLDS' 'SA1' 'TAS1' 'TASN' 'TASS' 'VIC1' nan]

# %%
combined_df['INTERVAL_DATETIME'] = pd.to_datetime(combined_df['INTERVAL_DATETIME'])

print(combined_df['INTERVAL_DATETIME'].dtype)
# Out:
# datetime64[ns]

# %%
earliest_date = combined_df['INTERVAL_DATETIME'].min()

latest_date = combined_df['INTERVAL_DATETIME'].max()

print(f"The earliest datetime value is: {earliest_date}")
print(f"The latest datetime value is: {latest_date}")
# Out:
# The earliest datetime value is: 2017-01-01 00:30:00
# The latest datetime value is: 2023-01-02 00:00:00

# %%
unique_regionids = combined_df['TYPE'].unique()

print("Unique Type values:")
print(unique_regionids)
# Out:
# Unique REGIONID values:
# ['MEASUREMENT' 'SATELLITE' nan 'DAILY']

# %% [markdown]
# ## Filtering out satelite and daily measurements....

# %%
combined_df = combined_df[combined_df['TYPE'] == 'MEASUREMENT']

# %%
combined_df.info
# Out:
# <bound method DataFrame.info of          I  ROOFTOP  ACTUAL    2   INTERVAL_DATETIME REGIONID  POWER   QI  \
# 0        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     NSW1    0.0  1.0
# 2        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLD1    0.0  1.0
# 4        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLDC    0.0  1.0
# 6        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLDN    0.0  1.0
# 8        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLDS    0.0  1.0
# ...     ..      ...     ...  ...                 ...      ...    ...  ...
# 1973752  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00      SA1    0.0  1.0
# 1973754  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     TAS1    0.0  1.0
# 1973755  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     TASN    0.0  1.0
# 1973758  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     TASS    0.0  1.0
# 1973760  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     VIC1    0.0  1.0
#
#                 TYPE          LASTCHANGED
# 0        MEASUREMENT  2020/05/01 00:50:42
# 2        MEASUREMENT  2020/05/01 00:50:42
# 4        MEASUREMENT  2020/05/01 00:50:42
# 6        MEASUREMENT  2020/05/01 00:50:42
# 8        MEASUREMENT  2020/05/01 00:50:42
# ...              ...                  ...
# 1973752  MEASUREMENT  2021/05/02 00:19:42
# 1973754  MEASUREMENT  2021/05/02 00:19:42
# 1973755  MEASUREMENT  2021/05/02 00:19:42
# 1973758  MEASUREMENT  2021/05/02 00:19:42
# 1973760  MEASUREMENT  2021/05/02 00:19:42
#
# [864260 rows x 10 columns]>

# %%
combined_df
# Out:
#          I  ROOFTOP  ACTUAL    2   INTERVAL_DATETIME REGIONID  POWER   QI  \
# 0        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     NSW1    0.0  1.0
# 2        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLD1    0.0  1.0
# 4        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLDC    0.0  1.0
# 6        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLDN    0.0  1.0
# 8        D  ROOFTOP  ACTUAL  2.0 2020-05-01 00:30:00     QLDS    0.0  1.0
# ...     ..      ...     ...  ...                 ...      ...    ...  ...
# 1973752  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00      SA1    0.0  1.0
# 1973754  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     TAS1    0.0  1.0
# 1973755  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     TASN    0.0  1.0
# 1973758  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     TASS    0.0  1.0
# 1973760  D  ROOFTOP  ACTUAL  2.0 2021-05-02 00:00:00     VIC1    0.0  1.0
#
#                 TYPE          LASTCHANGED
# 0        MEASUREMENT  2020/05/01 00:50:42
# 2        MEASUREMENT  2020/05/01 00:50:42
# 4        MEASUREMENT  2020/05/01 00:50:42
# 6        MEASUREMENT  2020/05/01 00:50:42
# 8        MEASUREMENT  2020/05/01 00:50:42
# ...              ...                  ...
# 1973752  MEASUREMENT  2021/05/02 00:19:42
# 1973754  MEASUREMENT  2021/05/02 00:19:42
# 1973755  MEASUREMENT  2021/05/02 00:19:42
# 1973758  MEASUREMENT  2021/05/02 00:19:42
# 1973760  MEASUREMENT  2021/05/02 00:19:42
#
# [864260 rows x 10 columns]

# %% [markdown]
# ## Merging all state region ID's into one for QLD and one for TAS

# %%
region_to_state = {
    'NSW1': 'NSW',
    'QLD1': 'QLD', 'QLDC': 'QLD', 'QLDN': 'QLD', 'QLDS': 'QLD',
    'SA1': 'SA',
    'TAS1': 'TAS', 'TASN': 'TAS', 'TASS': 'TAS',
    'VIC1': 'VIC'
    
}

combined_df['State'] = combined_df['REGIONID'].replace(region_to_state)

combined_df_grouped = combined_df.groupby(['State', 'INTERVAL_DATETIME'])['POWER'].sum().reset_index()

# %%
combined_df_grouped.head(50)
# Out:
#    State   INTERVAL_DATETIME    POWER
# 0    NSW 2018-03-06 09:30:00  427.281
# 1    NSW 2018-03-06 10:00:00  495.195
# 2    NSW 2018-03-06 10:30:00  516.137
# 3    NSW 2018-03-06 11:00:00  549.542
# 4    NSW 2018-03-06 11:30:00  556.764
# 5    NSW 2018-03-06 12:00:00  605.312
# 6    NSW 2018-03-06 12:30:00  622.850
# 7    NSW 2018-03-06 13:00:00  623.553
# 8    NSW 2018-03-06 13:30:00  620.090
# 9    NSW 2018-03-06 14:00:00  571.619
# 10   NSW 2018-03-06 14:30:00  527.098
# 11   NSW 2018-03-06 15:00:00  498.981
# 12   NSW 2018-03-06 15:30:00  398.394
# 13   NSW 2018-03-06 16:00:00  290.436
# 14   NSW 2018-03-06 16:30:00  216.720
# 15   NSW 2018-03-06 17:00:00  142.148
# 16   NSW 2018-03-06 17:30:00   84.038
# 17   NSW 2018-03-06 18:00:00   36.853
# 18   NSW 2018-03-06 18:30:00    6.750
# 19   NSW 2018-03-06 19:00:00    0.000
# 20   NSW 2018-03-06 19:30:00    0.000
# 21   NSW 2018-03-06 20:00:00    0.000
# 22   NSW 2018-03-06 20:30:00    0.000
# 23   NSW 2018-03-06 21:00:00    0.000
# 24   NSW 2018-03-06 21:30:00    0.000
# 25   NSW 2018-03-06 22:00:00    0.000
# 26   NSW 2018-03-06 22:30:00    0.000
# 27   NSW 2018-03-06 23:00:00    0.000
# 28   NSW 2018-03-06 23:30:00    0.000
# 29   NSW 2018-03-07 00:00:00    0.000
# 30   NSW 2018-03-07 00:30:00    0.000
# 31   NSW 2018-03-07 01:00:00    0.000
# 32   NSW 2018-03-07 01:30:00    0.000
# 33   NSW 2018-03-07 02:00:00    0.000
# 34   NSW 2018-03-07 02:30:00    0.000
# 35   NSW 2018-03-07 03:00:00    0.000
# 36   NSW 2018-03-07 03:30:00    0.000
# 37   NSW 2018-03-07 04:00:00    0.000
# 38   NSW 2018-03-07 04:30:00    0.000
# 39   NSW 2018-03-07 05:00:00    0.000
# 40   NSW 2018-03-07 05:30:00    0.000
# 41   NSW 2018-03-07 06:00:00    1.116
# 42   NSW 2018-03-07 06:30:00   31.686
# 43   NSW 2018-03-07 07:00:00   98.949
# 44   NSW 2018-03-07 07:30:00  183.276
# 45   NSW 2018-03-07 08:00:00  285.003
# 46   NSW 2018-03-07 08:30:00  389.016
# 47   NSW 2018-03-07 09:00:00  472.083
# 48   NSW 2018-03-07 09:30:00  541.238
# 49   NSW 2018-03-07 10:00:00  623.222

# %%
unique_regionids = combined_df_grouped['State'].unique()

print("Unique Type values:")
print(unique_regionids)
# Out:
# Unique Type values:
# ['NSW' 'QLD' 'SA' 'TAS' 'VIC']

# %%
earliest_date = combined_df_grouped['INTERVAL_DATETIME'].min()

latest_date = combined_df_grouped['INTERVAL_DATETIME'].max()

print(f"The earliest datetime value is: {earliest_date}")
print(f"The latest datetime value is: {latest_date}")
# Out:
# The earliest datetime value is: 2018-03-06 09:30:00
# The latest datetime value is: 2023-01-02 00:00:00

# %%
combined_df_grouped['INTERVAL_DATETIME'] = pd.to_datetime(combined_df_grouped['INTERVAL_DATETIME'])

combined_df_grouped_sorted = combined_df_grouped.sort_values('INTERVAL_DATETIME')

# %%
combined_df_grouped_sorted.head(20)
# Out:
#        State   INTERVAL_DATETIME    POWER
# 0        NSW 2018-03-06 09:30:00  427.281
# 84602    QLD 2018-03-06 09:30:00  730.922
# 338408   VIC 2018-03-06 09:30:00  520.076
# 253806   TAS 2018-03-06 09:30:00  122.102
# 169204    SA 2018-03-06 09:30:00  308.605
# 338409   VIC 2018-03-06 10:00:00  625.894
# 84603    QLD 2018-03-06 10:00:00  823.052
# 253807   TAS 2018-03-06 10:00:00  132.461
# 1        NSW 2018-03-06 10:00:00  495.195
# 169205    SA 2018-03-06 10:00:00  384.530
# 169206    SA 2018-03-06 10:30:00  457.406
# 253808   TAS 2018-03-06 10:30:00  125.542
# 338410   VIC 2018-03-06 10:30:00  715.790
# 2        NSW 2018-03-06 10:30:00  516.137
# 84604    QLD 2018-03-06 10:30:00  889.459
# 169207    SA 2018-03-06 11:00:00  508.956
# 253809   TAS 2018-03-06 11:00:00  154.182
# 84605    QLD 2018-03-06 11:00:00  870.885
# 338411   VIC 2018-03-06 11:00:00  753.883
# 3        NSW 2018-03-06 11:00:00  549.542

# %% [markdown]
# ## Looks ok - Lets plot a few days to see if it makes sense

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_2020 = combined_df_grouped_sorted[pd.to_datetime(combined_df_grouped_sorted['INTERVAL_DATETIME']).dt.year == 2020]

unique_days = df_2020['INTERVAL_DATETIME'].dt.date.unique()

selected_days = np.random.choice(unique_days, 10, replace=False)


for day in selected_days:
    
    df_day = df_2020[df_2020['INTERVAL_DATETIME'].dt.date == day]
    
    
    df_day_pivot = df_day.pivot(index='INTERVAL_DATETIME', columns='State', values='POWER')
    
    
    df_day_pivot.plot(kind='line', figsize=(15, 7))
    plt.title(f"Solar Power Production on {day}")
    plt.xlabel('Interval Datetime')
    plt.ylabel('Power Production')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()  
    plt.show()
